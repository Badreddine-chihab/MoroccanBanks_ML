# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rawdata= pd.read_csv('resources/clean_data.csv')

# %%
rawdata.head()
# Out:
#    Unnamed: 0   City       Business Name              Address Phone Number  \
# 0           0  adrej  BMCE BANK El Wafaa  225C+WRW, Fès 30050          NaN
# 1           1  adrej  BMCE BANK El Wafaa  225C+WRW, Fès 30050          NaN
# 2           2  adrej  BMCE BANK El Wafaa  225C+WRW, Fès 30050          NaN
# 3           3  adrej  BMCE BANK El Wafaa  225C+WRW, Fès 30050          NaN
# 4           4  adrej  BMCE BANK El Wafaa  225C+WRW, Fès 30050          NaN
#
#                                              Website Google Map ID  \
# 0  https://business.google.com/create?fp=34034433...           NaN
# 1  https://business.google.com/create?fp=34034433...           NaN
# 2  https://business.google.com/create?fp=34034433...           NaN
# 3  https://business.google.com/create?fp=34034433...           NaN
# 4  https://business.google.com/create?fp=34034433...           NaN
#
#                                          Review Text      Timestamp  Stars  \
# 0  GAb est sale\r\nPrès d'entrée d'immeuble et bo...   il y a 2 ans      1
# 1       Chef d'agence (une femme) est une hypocrite.   il y a 9 ans      2
# 2                                     Bonne services   il y a 4 ans      4
# 3  le pire service que j'ai jamais vu dans une ba...   il y a 2 ans      1
# 4                               No review text found  il y a 8 mois      5
#
#                 TrueTimestamp
# 0  2023-03-14 21:22:17.359491
# 1  2016-03-15 21:22:17.359491
# 2  2021-03-14 21:22:17.359491
# 3  2023-03-14 21:22:17.359491
# 4  2024-07-16 21:22:17.359491

# %%
#remove column
rawdata= rawdata.drop(columns=['Address','Timestamp',"Phone Number","Unnamed: 0",'Website','Google Map ID'])

# %% [markdown]
# remove rows where there is nor review text

# %%
rawdata = rawdata[rawdata["Review Text"] != "No review text"]
rawdata.head()
# Out:
#     City       Business Name  \
# 0  adrej  BMCE BANK El Wafaa
# 1  adrej  BMCE BANK El Wafaa
# 2  adrej  BMCE BANK El Wafaa
# 3  adrej  BMCE BANK El Wafaa
# 4  adrej  BMCE BANK El Wafaa
#
#                                          Review Text  Stars  \
# 0  GAb est sale\r\nPrès d'entrée d'immeuble et bo...      1
# 1       Chef d'agence (une femme) est une hypocrite.      2
# 2                                     Bonne services      4
# 3  le pire service que j'ai jamais vu dans une ba...      1
# 4                               No review text found      5
#
#                 TrueTimestamp
# 0  2023-03-14 21:22:17.359491
# 1  2016-03-15 21:22:17.359491
# 2  2021-03-14 21:22:17.359491
# 3  2023-03-14 21:22:17.359491
# 4  2024-07-16 21:22:17.359491

# %%
list(rawdata['Business Name'].unique())
# Out:
# ['BMCE BANK El Wafaa',
#  'بريد بنك',
#  'Al Akhdar Bank',
#  'Agence Bank of Africa',
#  'Attijariwafa Bank',
#  'Société Générale Bank',
#  'Bank of Africa',
#  'Banque Populaire',
#  'CIH Bank - Agence Mohammed V',
#  'Poste Maroc - Al Barid Bank',
#  'Crédit Agricole',
#  'BMCI',
#  'BRINKS MAROC-agadir-',
#  'CIH Bank- Agence Dakhla',
#  'Bank Al-Maghrib',
#  'Société Générale',
#  'Bank Al Yousr',
#  'Dar Al Amane Bank',
#  'Attijariwafa Bank - El Houda',
#  'Umnia Bank Agadir Kettani',
#  'CIH Bank',
#  'Poste Maroc - Al Barid Bank - Barid Cash',
#  'Espace Libre Service - Société Générale Maroc',
#  'Attijariwafa Bank - Agence Essalam Expansion',
#  'CIH Bank - Agence El Houda',
#  'Bank of Africa Talborjt',
#  'Bank of Africa - Agence Hassan 1er',
#  'Attijariwafa Bank - Agence Agadir Cadi Ayad',
#  'CIH Bank - Agence Hay Salam',
#  'Arab Bank',
#  "Centre d'estivage Banque Populaire",
#  'Bank of Africa - Batoir',
#  'Banque Populaire Siège Centre Sud',
#  'Bank Assafa',
#  'CIH Bank - Agence Bensergao',
#  'Attijariwafa Bank - Agence Agadir Hay Dakhla',
#  'Banque Populaire - Agence Bouabid',
#  'Bank of Africa - Agence Bensergao',
#  'CIH Bank - Agence Agadir Oufella',
#  'Attijariwafa Bank 11 Janvier',
#  'Banque Populaire - Agence Riad Salam',
#  'CIH bank',
#  'BARID BANK',
#  'Banque Populaire البنك الشعبي',
#  'Barid Bank',
#  'Attijari Wafa Banque',
#  'البنك الشعبي',
#  'La banque populaire',
#  'banque populaire',
#  'Bmce Bank',
#  'البريد بنك',
#  'CIH BANK',
#  'Crédit Agricole Du Maroc',
#  'CIH Banque',
#  'Banque populaire',
#  'Agence Crédit Agricole Ain Atiq',
#  'Bank of Africa Aïn Atiq',
#  'CIH',
#  'Attijariwafa Bank WIFAK2',
#  'Attijari WafaBanque',
#  'Banque populaure البنك الشعبي',
#  'Al Barid Bank Fès Narjis',
#  'Banque du Maroc',
#  'Banque Populaire - Molouk البنك الشعبي - ملوك',
#  'CFG Bank - Agence Fes',
#  'Banque BMCE',
#  'Agence Banque Populaire',
#  'Bank of Africa (BMCE)',
#  'bmce bank',
#  'La Banque Populaire',
#  'Banque Populaire Agence NESMA',
#  'Umnia Bank Fes Imam Malik',
#  'Banque Populaire بنك الشعبي',
#  'Crédit agricole_2',
#  'Banque CIH',
#  'banque populair',
#  "BANQUE POPULAIRE - Centre d'Affaire Fes Taza",
#  'Société Générale GAB',
#  'banque populaire lyrac',
#  'Société Générale Fes Ville Nouvelle',
#  'Agence BMCE Bank',
#  'Al Barid Bank FES Atlas',
#  "People's Bank Bensouda",
#  'BMCE Bank Fès CHEFCHAOUNI',
#  'La Poste Et Baridbank',
#  'Société Générale Fes Route de Sefrou',
#  'Al Barid Bank',
#  'Cih',
#  "Société Générale Fes Route d'Imouzzer",
#  'Société Générale Fes Route Ain Chkef',
#  'Cih Bank',
#  'البنك الشعبي Banque Populaire',
#  'Société Générale Fes Bensouda',
#  'BMCE Bank',
#  'Banque populaire البنك الشعبي',
#  'Attijariwafabank II',
#  'Al Barid Bank بريد المغرب',
#  'cih bank',
#  'Al barid bank',
#  'BANK OF AFRICA',
#  'Umnia Bank Azrou',
#  'CREDIT AGRICOLE',
#  'crédit Agricole',
#  'Attijariwafabank Driouch Expansion',
#  'attijariwafa bank',
#  'Banque Poulaire',
#  'Banque Populaire Abi Raqraq',
#  'Attijariwafa bank',
#  'Bank of Africa Agdal',
#  'Banque populaire Admime',
#  'BMCI Bank',
#  'CIH Bank - Agence',
#  'Attijariwafa Bank Dar Al Moukawil - التجاري وفا بنك دار المقاول',
#  'Société Générale Ait Melloul Zone Industrielle',
#  'Umnia Bank Ait Melloul',
#  'GAB banque populaire',
#  'Attijari wafa bank',
#  'Bank Populaire',
#  'Attijariwafa Bank Succursale Alaaroui',
#  'Société Générale Mont Arouit',
#  'Centre D\'affaires AttijariWafa Bank "Soufian"',
#  'Al Barid Bank البريد بنك',
#  'Banque Al-Maghrib',
#  'Banque populaire anif',
#  'Credit Agricole',
#  'Banque Populaire - Agence Aoulouz',
#  'Attijariwafa Bank - Aoulouz',
#  'Crédit Agricole - Agence Aourir',
#  'Poste Maroc - Barid Bank (Agence Aourir)',
#  'Attijari Wafa Bank Agance Route Larache',
#  'BMCE Bank of Africa',
#  'Banque Populaire, Agence Asni.',
#  'القرض العقاري و السياحي CIH',
#  'Crédit agricole',
#  'Banque Populaire Taza Anoual',
#  'Société Générale Taza',
#  'Sgmb Banque',
#  'Attijari Wafa Bank',
#  'Umnia Bank Taza',
#  'Agence Bank Assafa Taza',
#  'Banque Al Maghrib',
#  'bank populaire',
#  'Bmce Banque',
#  'التجاري وفابنك | Attijariwafa banq',
#  'Société Générale Taza My Youssef',
#  'Attijariwafa BANK : Agence Taza Hassan II',
#  'Cash Plus + ATM CIH Bank',
#  'التجاري وفا بنك',
#  'Banque Populaire - Agence Dar Dmana',
#  'Bank of Africa - Agence Chefchaoun',
#  'Banque populaire Guichet Automatique',
#  'Attijariwafa Bank (Siège Social)',
#  'Banque Populaire, Agence',
#  'Bank of Africa - Agence Ouazzane',
#  'Agence Banque Populaire Zoumi',
#  'Crédit Agricole du Maroc (Agence bvd. Hassan 2)',
#  'Société Générale Chaouen',
#  'BANQUE POPULAIRE',
#  'BMCE BANK',
#  'AttijariWafa bank',
#  'Agence wafabank mahatta',
#  'A côté de Banque Populaire',
#  'Crédit agricole agence ain asserdoun',
#  'Banque Populaire BCP',
#  'Bank AL YOUSR بنك اليسر',
#  'Société Générale El Wafa Beni Mellal',
#  'Umnia Bank Béni Mellal Atlas',
#  'CIH BANK El Arsa',
#  'Banque populaire agence annasr benslimane',
#  'AlBarid Bank بريد المغرب',
#  'Cih (Credit Immobilier Et Hotelier) (Agence Benslimane)',
#  'Umnia Bank Berkane',
#  'Banque AttijariWafa',
#  'Société Générale Berkane',
#  'Banque Populaire AL WIFAQ',
#  'Société Générale ANDALOUS',
#  'Crédit agricole CA',
#  'Bank Assafa - Agence Berkane',
#  'Société générale Bank',
#  'Crédit Agricoleالقرض الفلاحي',
#  'Agence Attijariwafa Bank',
#  'Wafa Bank',
#  'Umnia Bank Berrechid',
#  'Fondation Ardi Micro Crédit (Groupe Crédit Agricole)',
#  'Banque Populaire Biougra',
#  'Banque Populaire Chtouka',
#  'Société Générale Biougra',
#  'BANQUE POPULAIRE AG: IKAOUEN',
#  'البنك الشعبي بوفكران',
#  'Credit Agricole Du Maroc',
#  'Banque crédit agricole',
#  'التجاري وفابنك',
#  'Umnia Bank Khouribga',
#  'crédit agricole',
#  'Banque populaire Boumia',
#  'Agence BMCI',
#  'BANK OF AFRICA BOUSKOURA',
#  'CFG Bank - GAB Kitéa Géant Bouskoura',
#  'Banque crédit du maroc',
#  'Banque Populaire Oulad Haddou',
#  'Attijari bank',
#  'Umnia Bank Casablanca Sidi Maarouf',
#  'Espace client AttijariWafa Bank',
#  'Société Générale Sidi Maarouf',
#  'Académie BANK OF AFRICA',
#  'Banque Assafa Ennakhil Hay Riad',
#  'Bureau National de la Banque Africaine de Développement',
#  'Al Barid bank',
#  'albarid bank',
#  'CFG Bank - agence Hay Riad',
#  'Banque Islamique de Développement',
#  'Attijariwafa Bank Ennakhil',
#  'Banque Populaire Agence Almaghrib Alarabi',
#  'Bank Populaire Centre Temara',
#  'Banque Populaire Oulad Mtaa',
#  'Attijariwafa Bank GAB',
#  'Umnia Bank',
#  'banque populaire agens alfirdaws',
#  'Société Générale Rabat Aswak Essalam',
#  'Crédit Agricole du Maroc - Agence Smart',
#  'Banque Populaire, Agence Shems',
#  'Credit Agricole Du Maroc ( center )',
#  'CIH agence Riad Al Andalous',
#  'ATTIJARIWAFA Bank',
#  'Umnia Bank Fkih Ben Saleh',
#  'Albarid Banque - بنك البريد',
#  'Banque Populaire Cité Djemaa',
#  'Bank Al Amal',
#  'Bank chaabi',
#  'CIH BANK Agence Hay Mouhammadi',
#  'Bank Of Africa, Agence Route El Jadida, Maarif.',
#  'Attijariwafa Bank, Agence Ali Yaata.',
#  'Attijariwafa bank Casa Horizon',
#  'Arab Bank Plc',
#  'Al barid Bank',
#  'BANK OF AFRICA, Agence Abdelmoumen, Casablanca.',
#  'Umnia Bank Casablanca Derb Ghalef',
#  'Bank Al Karam_Siège Social',
#  'Attijariwafabank, Agence Hay El Hanaa, Hay Hassani.',
#  'ATTIJARIWAFA BANK Sidi Abderrahmane',
#  'Umnia Bank Casablanca Souna',
#  'CFG Bank - Agence Oasis',
#  'AL BARID BANK Bd Panoramique',
#  'AttijariWafa Bank',
#  'Umnia Bank Casablanca Ain Sebaa.',
#  'التجاري وفا بنك ابن تاشفين AttijariWafa Bank Ibn Tachfine',
#  'CIH Bank - Agence Ifriquia',
#  '.CIH Bank, Agence Brahim Roudani',
#  'CFG Bank - Gab station Shell Romandie',
#  'Siège Social Banque Société Générale',
#  'CFG Bank - Agence Palmiers',
#  'Bank of Africa Siège Social',
#  'CFG Bank - GAB station Shell Oasis Les stades - Drive',
#  'CIH Bank, Agence Place du Marché, Casablanca.',
#  'Siège C - BANK OF AFRICA',
#  'Banque Populaire, Agence AL ÎRFANE, Casablanca.',
#  'Banque populaire beauséjour',
#  'Banque Populaire Hay Sadri',
#  'Banque Populaire El Khatabi',
#  'Attijariwafa bank Bd Moulay Idriss I',
#  'AttijariWafa Bank Blaise Pascal',
#  'CIH Bank Yaacoub Al Mansour',
#  'Banque Populaire El Hamd',
#  'Banque Centrale Populaire',
#  'BMCE BANK OF AFRICA, Agence Casablanca, Houssine Soussi',
#  'Attijariwafa Bank Oued Eddahab Expansion',
#  'Bank Of Africa, Agence Al Massira, Maarif.',
#  'Bank Al Maghrib',
#  'CFG Bank - GAB hôtel Kenzi Tower',
#  'Al Barid Bank Ibn Tachfine',
#  'Agence CIH',
#  'Attijariwafa Bank, Agence Abdelmoumen, Maarif.',
#  'Citibank',
#  'Attijariwafa bank Casa Rue de Sebta',
#  'Banque Populaire Attawfiq',
#  'Attijariwafa bank Casa Rue De Rome',
#  'Socièté Générale Bank',
#  'Banque Chaabi',
#  'Société Générale Dakhla',
#  'CIH Bank AG DAKHLA',
#  'Société Générale Dar Bouazza',
#  'BMCI - Agence Dar Bouazza',
#  'بنك الصفاء',
#  'CIH Bank - Agence Tanger Hay Hassani',
#  'atijari wafabank',
#  'Banque Populaire - Agence Anfa',
#  'Bank of Africa - Agence Arabie Saoudite',
#  'CIH Bank - Agence Souani',
#  'Banque Populaire - Agence Sidi Driss',
#  'Banque Populaire Offshore',
#  'Attijariwafa Bank - Agence My Ismail',
#  'Umnia Bank Tanger Dar Tounsi',
#  'Annexe Administrative 24-Bank Chaabi',
#  'Agence Attijari Wafabank Souani',
#  'BMCI Bank - Agence Tanger City Center',
#  'CIH BANK ATM',
#  'Bank Al Karam - Agence Tanger',
#  'CIH Bank - Agence Tanger Irfan',
#  'Bank of Africa_Offshore',
#  'Société Générale Tanger Place Toro',
#  'Umnia Bank Tanger Nejma',
#  'Poste Maroc - Al Barid Bank (Agence Castilla)',
#  'Société générale Tanger Malabata',
#  'Banque attijariwafa',
#  'Poste Barid Banque',
#  'Guichet Attijariwafa Bank',
#  'Umnia Bank Inzegane',
#  'Guichet CIH Bank',
#  'CIH - Agence Inzegane II',
#  'Banque Populaire Agence Annahda',
#  'البنك المغربي للتجارة الخارجية',
#  'Crédit Agricoles',
#  'CFG Bank - GAB Carrefour Temara',
#  'بنك المغرب Bank Al Maghrib',
#  'Banque Populaire D El Jadida',
#  "Centre d'affaire banque populaire",
#  'Umnia Bank El Jadida Doukkala',
#  'Société Générale Kalaat Sraghna',
#  'al barid bank',
#  'Société Générale El Kalaa des Sraghnas Bd Des FAR',
#  'CIH Bank kalaa des sraghna',
#  'Umnia Bank EL Kelâa des Sraghna',
#  'وكالة البنك المغربي للتجارة الخارجية',
#  'attijari wafa bank',
#  'Club CIH Bank',
#  'Crédit agricole Ibn tachfin Errachidia',
#  'Banque Populaire régional Errachidia',
#  'Umnia Bank Errachidia',
#  'Société Générale Errachidia',
#  'Banque Populaire centre ville Errachidia',
#  'Crédit agricole du Maroc',
#  'Banque Populaire -Agence',
#  'Credit agricole',
#  'Société Générale Essaouira Premium',
#  'Bank Of Africa (BMCE Group)',
#  'Société Générale Essaouira Driss 1er',
#  'Centre de Vacances Bank Al Maghrib',
#  'Banque populaire agence jemaat Fedalate',
#  'Société Générale Fes Medina Rsif',
#  'Banque Populaire Agence Al Boustane',
#  'Agence Al Barid Bank FES HAY TARIK',
#  'Banque Populaire Agence Ain Smen',
#  'siege regional de la banque populaire Fes Boulmane',
#  'Banque CIH Agence Adarissa',
#  'BMCE banque',
#  'Banque Populaire Soundous',
#  'Banque Populaire oued fes',
#  'Société Générale Fes Boujloud',
#  'Banque populaire Agence Zenaga',
#  'Agence Société Générale',
#  'Société Générale - GAB FKIH BEN SALAH',
#  'Al Barid Bank Guelmim',
#  'Umnia Bank Guelmim Bab Essahra',
#  'Banque Populaire Ibn Batota',
#  'Société Générale Guercif',
#  'CRÉDIT AGRICOLE',
#  'Groupe Scolaire de La Fondation Banque Populaire_Tanger',
#  'banque populaire Had kourt البنك الشعبي حد كورت',
#  'Société Générale Temara Massira',
#  'Agence Attajariwafa Banque',
#  'Umnia Bank Temara',
#  'barid bank',
#  'Société Générale Temara Aswak Essalam',
#  'Crédit Agricole du Maroc',
#  'Assafa bank',
#  'Banque Populaire agence al moustakbal',
#  "Centre d'Estivage Banque Populaire_ifrane",
#  'GAB Société Générale Maroc',
#  'Centre Estivage Bank Al Maghrib',
#  'Al Barid Bank البريد بنك ايموزار كندر',
#  'Credit Agricole de Maroc',
#  'Banque Populaire -Agence Carrefour',
#  'Banque Populaire.',
#  'banque populaire البنك الشعبي',
#  'البنك الشعبي -وكالة الرمل Banque Populaire-agence rmel',
#  'Society General Bank',
#  'Crédit Agricole - Agence Inzegane Med V',
#  'Credit Agricole Du Maroc - Inezgane',
#  'Bank Assafa - Siège Social']

# %%
from rapidfuzz import process, fuzz

# Define known bank names
bank_names = {
    "CIH": ['Cih','Banque CIH','CIH','CIH bank','CIH Bank - Agence Mohammed V','CIH Bank- Agence Dakhla',
            'CIH Bank - Agence Hay Salam','CIH Bank - Agence Bensergao','CIH BANK','CIH Banque','CIH Bank - Agence'],
    "Attijariwafa Bank": ["Attijari", "Attijari Wafabank", "attijari fes", "attijari bank",
                          'Attijariwafa Bank - El Houda','Attijariwafa Bank - Agence Essalam Expansion',
                          'Attijariwafa Bank - Agence Agadir Cadi Ayad','Attijariwafa Bank - Agence Agadir Hay Dakhla',
                          'Attijariwafa Bank 11 Janvier','Attijari Wafa Banque','Attijariwafa bank','Attijari wafa bank'],
    "BMCE Bank": ["BMCE BANK El Wafaa", "BMCE Bank", "bmce fes", "bmcebank"],
    "Banque Populaire": ["BANQUE POPULAIRE - Centre d'Affaire Fes Taza",'banque populaire',"Banque Populaire",
                          "B. Populaire", "populaire fes","Centre d'estivage Banque Populaire",'Banque Populaire Siège Centre Sud',
                          'Banque Populaire - Agence Bouabid','Banque Populaire - Agence Riad Salam','Banque Populaire البنك الشعبي',
                          'La banque populaire','banque populaire','Banque populaire','Agence Banque Populaire',
                          'Banque Poulaire','Banque populaire Admime'],
    "Al Barid Bank": ['Poste Maroc - Al Barid Bank','Poste Maroc - Al Barid Bank - Barid Cash','Barid Bank',
                      'BARID BANK','Al Barid Bank Fès Narjis','Al Barid Bank'],
    "Bank of Africa":['Agence Bank of Africa','Bank of Africa - Agence Hassan 1er','Bank of Africa Talborjt',
                      'Bank of Africa - Batoir','Bank of Africa - Agence Bensergao','Bank of Africa (BMCE)',
                      'BMCE','bmce bank','Banque BMCE', 'Bank of Africa Agdal'],
    'Bank Assafa': [],
    "BMCI":['BMCI Bank'],
    "Arab Bank": [],
    "Bank Al-Maghrib": [],
    "Bank Al Yousr": [],
    "Crédit Agricole": ['Crédit Agricole Du Maroc','crédit agricole','CREDIT AGRICOLE'],
    "Société Générale": ['Société Générale Bank','Espace Libre Service - Société Générale Maroc','Société Générale GAB']
}

# Function to match business names
def match_bank(name):
    name = name.lower().strip()  # Normalize input
    best_match = "Other"
    highest_score = 0

    for bank, variations in bank_names.items():
        if not variations:  # Skip empty lists
            continue

        match, score, _ = process.extractOne(name, variations, scorer=fuzz.partial_ratio)

        if match and score > highest_score:  # Ensure match is valid
            best_match = bank
            highest_score = score

    return best_match if highest_score >= 80 else "Other"

# Apply function to the dataset
rawdata["Business Name"] = rawdata["Business Name"].apply(match_bank)

# %%
#Making sure every rating is within the range 1-5
rawdata["Stars"].describe()
# Out:
# count    13981.000000
# mean         2.686217
# std          1.772554
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max          5.000000
# Name: Stars, dtype: float64

# %% [markdown]
# Let's work with only few big cities

# %%
# List of valid Moroccan cities
valid_cities = [
    "agadir","ifrane","dakhla","fes","errachidia","casablanca","berkane","azilal","harhoura","el+jadida",
]

rawdata["City"] = rawdata["City"].str.lower().str.strip()

# Remove rows where the city is not in the valid list
rawdata = rawdata[rawdata["City"].isin(valid_cities)]
list(rawdata["City"].unique())
# Out:
# ['agadir',
#  'azilal',
#  'berkane',
#  'casablanca',
#  'dakhla',
#  'el+jadida',
#  'errachidia',
#  'fes',
#  'harhoura',
#  'ifrane']

# %%
rawdata.describe()
# Out:
#              Stars
# count  5235.000000
# mean      2.584145
# std       1.761890
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       5.000000
# max       5.000000

# %%
rawdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5235 entries, 46 to 13258
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   City           5235 non-null   object
#  1   Business Name  5235 non-null   object
#  2   Review Text    5235 non-null   object
#  3   Stars          5235 non-null   int64
#  4   TrueTimestamp  5235 non-null   object
#  5   Matched Bank   5235 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 286.3+ KB

# %%
rawdata.head()
# Out:
#       City      Business Name  \
# 46  agadir  Attijariwafa Bank
# 47  agadir  Attijariwafa Bank
# 48  agadir  Attijariwafa Bank
# 49  agadir  Attijariwafa Bank
# 50  agadir  Attijariwafa Bank
#
#                                           Review Text  Stars  \
# 46  Beaucoup des clients qui attends outside alors...      2
# 47                                        Bon service      4
# 48                              Service👍🏽👍🏽👍🏽👍🏽👍🏽👍🏽 …      5
# 49                               No review text found      5
# 50  Le service est nul, j'ai pas de compte bancair...      1
#
#                  TrueTimestamp       Matched Bank
# 46  2022-03-14 21:22:17.360486  Attijariwafa Bank
# 47  2023-03-14 21:22:17.360486  Attijariwafa Bank
# 48  2024-12-13 21:22:17.360486  Attijariwafa Bank
# 49  2012-03-16 21:22:17.360486  Attijariwafa Bank
# 50  2024-10-14 21:22:17.360486  Attijariwafa Bank

# %% [markdown]
# SAVING TO A NEW CSV

# %%
rawdata.to_csv("data/updated_dataset.csv", index=False)

# %% [markdown]
# SPLITTING THE DATASET INTO 2 : ONE FOR STARS OTHER ONE FOR REVIEWS

# %%
# Split into two datasets
df_star = rawdata[["City", "Business Name", "Stars", "TrueTimestamp"]]  # Star Dataset
df_review = rawdata[["City", "Business Name", "Review Text", "TrueTimestamp"]]  # Review Dataset

# Save both datasets
df_star.to_csv("data/star_dataset.csv", index=False)
df_review.to_csv("data/review_dataset.csv", index=False)

# Show first few rows for confirmation
print("Star Dataset:")
print(df_star.head())

print("\nReview Dataset:")
print(df_review.head())
# Out:
# Star Dataset:
#       City      Business Name  Stars               TrueTimestamp
# 46  agadir  Attijariwafa Bank      2  2022-03-14 21:22:17.360486
# 47  agadir  Attijariwafa Bank      4  2023-03-14 21:22:17.360486
# 48  agadir  Attijariwafa Bank      5  2024-12-13 21:22:17.360486
# 49  agadir  Attijariwafa Bank      5  2012-03-16 21:22:17.360486
# 50  agadir  Attijariwafa Bank      1  2024-10-14 21:22:17.360486
#
# Review Dataset:
#       City      Business Name  \
# 46  agadir  Attijariwafa Bank
# 47  agadir  Attijariwafa Bank
# 48  agadir  Attijariwafa Bank
# 49  agadir  Attijariwafa Bank
# 50  agadir  Attijariwafa Bank
#
#                                           Review Text  \
# 46  Beaucoup des clients qui attends outside alors...
# 47                                        Bon service
# 48                              Service👍🏽👍🏽👍🏽👍🏽👍🏽👍🏽 …
# 49                               No review text found
# 50  Le service est nul, j'ai pas de compte bancair...
#
#                  TrueTimestamp
# 46  2022-03-14 21:22:17.360486
# 47  2023-03-14 21:22:17.360486
# 48  2024-12-13 21:22:17.360486
# 49  2012-03-16 21:22:17.360486
# 50  2024-10-14 21:22:17.360486

# %% [markdown]
# 1️⃣ Star Dataset → For numerical analysis of ratings.
# 2️⃣ Review Dataset → For NLP & sentiment analysis
